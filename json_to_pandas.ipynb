# %%
'''
This python script will create a pandas dataframe in the following format:
id | text (english) | title | url (en-wiki) | topic
parsing from the english wikipedia set, only the topics / id / revid / article name / url / english text 
will parse. 

JSON format: {"id": "", "url":"", "title": "", "text": "..."}
JSON format extracted using: https://github.com/attardi/wikiextractor

https://www.mediawiki.org/wiki/API:Categories for topic
'''

import json
import pandas as pd
import requests

# Currently goes through 1 json instance at a time to make 1 csv for the articles in that json file.
pandas_df = pd.read_json("wiki_00.json",lines="True")
print(pandas_df.head())
# Out:
#     id                                               text      title  \
# 0   12  Anarchism\n\nAnarchism is an anti-authoritaria...  Anarchism
# 1   25  Autism\n\nAutism is a developmental disorder c...     Autism
# 2   39  Albedo\n\nAlbedo () (, meaning 'whiteness') is...     Albedo
# 3  290  A\n\nA (named , plural "As", "A's", "a"s, "a's...          A
# 4  303  Alabama\n\nAlabama () is a state in the southe...    Alabama
#
#                                        url
# 0   https://en.wikipedia.org/wiki?curid=12
# 1   https://en.wikipedia.org/wiki?curid=25
# 2   https://en.wikipedia.org/wiki?curid=39
# 3  https://en.wikipedia.org/wiki?curid=290
# 4  https://en.wikipedia.org/wiki?curid=303

# %%
''' 
INDEXING:
id=0,text=1, title=2, url=3, topic (will be)=4
---

Next, can get its topic by: https://www.mediawiki.org/wiki/API:Categories for topic


'''
# default value is NONE for topic
pandas_df['topic']='NONE' 
pandas_df = pandas_df.astype('object')
sess = requests.Session()
URL = "https://en.wikipedia.org/w/api.php"
# Go through the URLs in the dataset: 

for index, row in pandas_df.iterrows():
    title = row['title']
    params = {
    "action": "query",
    "format": "json",
    "titles": title,
    "prop": "categories",
    }


    R = sess.get(url=URL, params=params)
    cat_dat = R.json()
#     print(index, cat_dat)
    if 'continue' in cat_dat.keys():
        number = cat_dat['continue']['clcontinue'].split("|")[0]
        # All categories associated are within this list. 
        # Just grab first one that appears. 
        # Format of categories: "categories": [{ns:xx, title:xx}, {..}, {...}]
        # Format: "title": "Category:1985 births" --> split = ["category", "1985 births"]
        # Could get all topics from just list_cat. 
        # add all categories in a list
        list_cat = cat_dat['query']['pages'][number]['categories']
        topic_cat = [cat['title'].split(':')[1] for cat in list_cat]

        # just keep the first category
        #         topic_cat = list_cat['title'].split(":")[1]
        print(topic_cat)

        # Change 'topic' to be the topic_cat
        row['topic'] = topic_cat
        pandas_df.loc[index, 'topic']= topic_cat

print(pandas_df.head())
# Out:
# ['All articles lacking reliable references', 'All articles with unsourced statements', 'Anarchism', 'Anti-capitalism', 'Anti-fascism', 'Articles containing Spanish-language text', 'Articles lacking reliable references from March 2019', 'Articles prone to spam from November 2014', 'Articles with short description', 'Articles with unsourced statements from March 2019']
# ['All Wikipedia articles written in American English', 'All articles containing potentially dated statements', 'Articles containing potentially dated statements from 2015', 'Articles containing potentially dated statements from 2017', 'Articles containing video clips', 'Articles with Curlie links', 'Articles with short description', 'Autism', 'CS1 German-language sources (de)', 'CS1 Spanish-language sources (es)']
# ['All articles with unsourced statements', 'Articles containing Latin-language text', 'Articles with unsourced statements from December 2017', 'Articles with unsourced statements from January 2018', 'Articles with unsourced statements from November 2013', 'CS1', 'CS1 maint', 'Climate forcing', 'Climatology', 'Electromagnetic radiation']
# ['All articles with unsourced statements', 'Articles with short description', 'Articles with unsourced statements from May 2018', 'Articles with unsourced statements from October 2015', 'CS1', 'ISO basic Latin letters', 'Use dmy dates from June 2013', 'Vowel letters', "Wikipedia articles incorporating a citation from Collier's Encyclopedia", 'Wikipedia articles incorporating a citation from The American Cyclopaedia']
# ['1819 establishments in the United States', 'AC with 14 elements', 'Alabama', 'All articles containing potentially dated statements', 'All articles to be expanded', 'All articles with failed verification', 'All articles with unsourced statements', 'Articles containing Latin-language text', 'Articles containing potentially dated statements from 1999', 'Articles containing potentially dated statements from 2010']
# ['Achaean Leaders', 'All articles with dead external links', 'Articles containing Ancient Greek-language text', 'Articles with dead external links from June 2017', 'Articles with permanently dead external links', 'Articles with short description', 'Characters in Greek mythology', 'Characters in the Iliad', 'Commons category link is on Wikidata', 'Demigods of Classical mythology']
# ['1809 births', '1860 United States presidential candidates', '1864 United States presidential candidates', '1865 deaths', '19th-century American politicians', '19th-century Presidents of the United States', 'AC with 21 elements', 'Abraham Lincoln', 'All Wikipedia articles in need of updating', 'All Wikipedia articles needing clarification']
# ['322 BC deaths', '384 BC births', '4th-century BC births', '4th-century BC deaths', '4th-century BC philosophers', '4th-century BC writers', 'AC with 20 elements', 'Academic philosophers', 'Acting theorists', 'Ancient Greek biologists']
# ['1928 compositions', 'All articles with unsourced statements', 'Articles with International Music Score Library Project links', 'Articles with unsourced statements from December 2018', 'Compositions by George Gershwin', 'Grammy Hall of Fame Award recipients', 'Music about Paris', 'Music commissioned by the New York Philharmonic', 'Pages using authority control with parameters', 'Symphonic poems']
# ['1929 establishments in California', 'Academy Awards', 'All articles containing potentially dated statements', 'All articles to be expanded', 'American annual television specials', 'American film awards', 'Annual events in Los Angeles County, California', 'Articles containing potentially dated statements from 2018', 'Articles needing POV-check from April 2016', 'Articles to be expanded from February 2016']
# ['All articles with dead external links', 'Altruism', 'Articles with dead external links from December 2017', 'Articles with permanently dead external links', 'Auguste Comte', 'CS1 maint', 'Defence mechanisms', 'Evolutionary psychology', 'Interpersonal relationships', 'Moral psychology']
# ['1905 births', '1982 deaths', '20th-century American dramatists and playwrights', '20th-century American novelists', '20th-century American philosophers', '20th-century American women writers', '20th-century American writers', '20th-century Russian philosophers', '20th-century atheists', '20th-century essayists']
# ['1947 births', '20th-century French mathematicians', '21st-century mathematicians', 'Articles with hCards', 'CS1 maint', 'Clay Research Award recipients', 'Collège de France faculty', 'Differential geometers', 'Fields Medalists', 'Foreign Members of the Russian Academy of Sciences']
# ['1885 births', '1981 deaths', 'American film directors', 'American film producers', 'American male screenwriters', 'Articles with hCards', 'Burials at San Fernando Mission Cemetery', 'Canadian emigrants to the United States', 'Commons category link is on Wikidata', 'Disease-related deaths in California']
# ['1962 establishments in Africa', '1962 establishments in Algeria', 'Algeria', 'All accuracy disputes', 'All articles lacking reliable references', 'All articles needing additional references', 'All articles with unsourced statements', 'Arab republics', 'Arabic-speaking countries and territories', 'Articles containing Arabic-language text']
# ['All articles with unsourced statements', 'Articles containing Ancient Greek-language text', 'Articles containing French-language text', 'Articles containing Latin-language text', 'Articles with short description', 'Articles with unsourced statements from August 2018', 'Articles with unsourced statements from November 2012', 'CS1', 'CS1 Spanish-language sources (es)', 'CS1 maint']
# ['Alchemy', 'All articles with unsourced statements', 'Articles containing Ancient Greek-language text', 'Articles containing Arabic-language text', 'Articles containing Latin-language text', 'Articles with short description', 'Articles with unsourced statements from February 2013', 'Articles with unsourced statements from September 2015', 'CS1 errors', 'Commons category link is on Wikidata']
# ['ASCII', 'All Wikipedia articles written in American English', 'All articles with unsourced statements', 'Articles with hAudio microformats', 'Articles with short description', 'Articles with unsourced statements from June 2016', 'Character sets', 'Commons category link is on Wikidata', 'Computer-related introductions in 1963', 'Latin-script representations']
# ['All articles with unsourced statements', 'Apollo', 'Articles containing Ancient Greek-language text', 'Articles containing Hittite-language text', 'Articles containing Latin-language text', 'Articles containing Mycenaean Greek-language text', 'Articles having same image on Wikidata and Wikipedia', 'Articles with short description', 'Articles with unsourced statements from March 2019', 'Arts gods']
# ['1970 births', '20th-century American businesspeople', '21st-century American businesspeople', 'All articles containing potentially dated statements', 'All articles with dead external links', 'American autobiographers', 'American investors', 'American male tennis players', 'American people of Armenian descent', 'American people of Iranian-Assyrian descent']
# ['Afroasiatic languages', 'Afroasiatic peoples', 'All articles lacking in-text citations', 'All articles with failed verification', 'All articles with unsourced statements', 'Articles lacking in-text citations from September 2016', 'Articles with Russian-language external links', 'Articles with failed verification from February 2019', 'Articles with short description', 'Articles with unsourced statements from December 2016']
# ['1278 establishments in Europe', 'All articles with dead external links', 'Andorra', 'Articles containing Catalan-language text', 'Articles with Catalan-language external links', 'Articles with Curlie links', 'Articles with French-language external links', 'Articles with dead external links from March 2019', 'Articles with hAudio microformats', 'Articles with short description']
# ['1945 British novels', 'All articles with unsourced statements', 'Allegory', 'Animal Farm', 'Articles containing French-language text', 'Articles with Project Gutenberg links', 'Articles with Wikilivres links', 'Articles with short description', 'Articles with unsourced statements from February 2019', 'British novellas']
# ['Amphibians', 'Amphibious organisms', "Articles with 'species' microformats", 'Articles with short description', 'CS1 maint', 'Commons category link is on Wikidata', 'Extant Late Devonian first appearances', 'Featured articles', 'Use mdy dates from June 2013', 'Wikipedia articles with BNF identifiers']
#     id                                               text      title  \
# 0   12  Anarchism\n\nAnarchism is an anti-authoritaria...  Anarchism
# 1   25  Autism\n\nAutism is a developmental disorder c...     Autism
# 2   39  Albedo\n\nAlbedo () (, meaning 'whiteness') is...     Albedo
# 3  290  A\n\nA (named , plural "As", "A's", "a"s, "a's...          A
# 4  303  Alabama\n\nAlabama () is a state in the southe...    Alabama
#
#                                        url  \
# 0   https://en.wikipedia.org/wiki?curid=12
# 1   https://en.wikipedia.org/wiki?curid=25
# 2   https://en.wikipedia.org/wiki?curid=39
# 3  https://en.wikipedia.org/wiki?curid=290
# 4  https://en.wikipedia.org/wiki?curid=303
#
#                                                topic
# 0  [All articles lacking reliable references, All...
# 1  [All Wikipedia articles written in American En...
# 2  [All articles with unsourced statements, Artic...
# 3  [All articles with unsourced statements, Artic...
# 4  [1819 establishments in the United States, AC ...

# %%
# Finally, place into csv for use in other people's code! (If you are using this dataset in other analysis)

pandas_df.to_csv(path_or_buf='wikipandas.csv', index=False)


# To see how the output can be used again, un-comment these two lines:
#new_pandas = pd.read_csv('wikipandas.csv')
#print(new_pandas.head())
